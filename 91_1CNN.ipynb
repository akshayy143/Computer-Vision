# %%
#CNN Architech

# %% [markdown]
# ![Screenshot 2026-04-03 101803.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-03 095505.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-03 101959.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-03 102454.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-03 103601.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-03 104225.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-03 104324.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-03 104444.png](data:image/png;base64,...)

# %%
vgg16_model.summaer()

# %% [markdown]
# ![Screenshot 2026-04-03 104716.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-03 104802.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-03 104943.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-03 105146.png](data:image/png;base64,...)

# %% [markdown]
# **Transfer Learning**

# %% [markdown]
# ![Screenshot 2026-04-03 105531.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-03 105628.png](data:image/png;base64,...)

# %%
vgg16_model.summery()

# %% [markdown]
# ![Screenshot 2026-04-03 105958.png](data:image/png;base64,...)

# %% [markdown]
# here after applying transfer learning accuracy goes from 0.15 % to accuracy 84% this is the power of thing![Screenshot 2026-04-03 110122.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-03 110313.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-03 110403.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-03 110510.png](data:image/png;base64,...)
